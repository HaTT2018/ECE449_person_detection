# %% [markdown]
# # Run

# %%
! python train.py --epoch 300 --data data.yaml --cfg yolov5s.yaml --weights '' --batch-size 16
# Out:
# github: skipping check (not a git repository)
# YOLOv5  2021-5-10 torch 1.8.1+cu111 CUDA:0 (GeForce RTX 3060 Laptop GPU, 6144.0MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='yolov5s.yaml', data='data.yaml', device='', entity=None, epochs=300, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='exp', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs\\train\\exp3', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights="''", workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %% [markdown]
# # Visualization

# %%
import os
result_location = r'C:\Users\10169\Desktop\ECE449\yolov5\runs\train\\'
result_dir_list = os.listdir(train_label_location)
result_dir = result_dir_list[-1]
result_location = result_location + result_dir

# %%
result_location
# Out:
# 'C:\\Users\\10169\\Desktop\\ECE449\\yolov5\\runs\\train\\\\exp3'

# %%
from IPython.display import Image

# %% [markdown]
# ## Testing labels

# %%
pred_path = result_location + '\\' + 'test_batch0_labels.jpg'
Image(filename=pred_path, width=600)

# %% [markdown]
# ## Test predictions

# %%
pred_path = result_location + '\\' + 'test_batch0_pred.jpg'
Image(filename=pred_path, width=600)

# %% [markdown]
# ## Results

# %%
pred_path = result_location + '\\' + 'results.png'
Image(filename=pred_path, width=800)
